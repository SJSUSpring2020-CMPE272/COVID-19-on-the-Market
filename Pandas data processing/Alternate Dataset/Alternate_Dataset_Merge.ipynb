# %%
import pandas as pd
import numpy as np

# %%
threeM_TB = pd.read_csv("3-Month Treasury Bill: Secondary Market US.csv")
C19_US = pd.read_csv("Covid-19 Data in US - .csv")
C19_NM = pd.read_csv("Covid-19 Data in NM - .csv")
WTIoil = pd.read_csv("WTI Oil Prices - .csv")
stkmkt = pd.read_csv("Stock market.csv")
unemplyNM = pd.read_csv("NM Unemployment insurance.csv")
oilNM = pd.read_csv("NM Oil & Gas.csv")
#laborUS = pd.read_csv("Labor force Data US - .csv")
#laborNM = pd.read_csv("Labor force Data NM - .csv")
#mortgage = pd.read_csv("Mortgage rates US (%).csv")
#hotel_ALB = pd.read_csv("Hotel Stats Albuquerque.csv")
bankLoan = pd.read_csv("Bank Prime Loan US.csv")
#airprtALB = pd.read_csv("ABQ Airport Statistics.csv")

# %%
# Out:
#     stfips  areatype  area  periodyear  periodtype  period  rigs
# 0       35        77     0        2019           3       1   108
# 1       35        77     0        2019           3       2   110
# 2       35        77     0        2019           3       3   105
# 3       35        77     0        2019           3       4   105
# 4       35        77     0        2019           3       5   102
# 5       35        77     0        2019           3       6   100
# 6       35        77     0        2019           3       7   105
# 7       35        77     0        2019           3       8   109
# 8       35        77     0        2019           3       9   109
# 9       35        77     0        2019           3      10   112
# 10      35        77     0        2019           3      11   105
# 11      35        77     0        2019           3      12   103
# 12      35        77     0        2020           3       1   106
# ...
